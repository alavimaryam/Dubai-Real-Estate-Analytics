# %% [markdown]
# <a href="https://colab.research.google.com/github/alavimaryam/Dubai-Real-Estate-Analytics/blob/main/notebooks/01_Data_Exploration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alavimaryam/Dubai-Real-Estate-Analytics/refs/heads/main/data/dubai_residential_data_2026.csv"

df = pd.read_csv(url)

df.head()
# Out:
#   INSTANCE_DATE PROCEDURE_EN IS_FREE_HOLD_EN                  AREA_EN  \
# 0    2026-01-02         Sale       Free Hold             BURJ KHALIFA
# 1    2026-01-02         Sale       Free Hold             BURJ KHALIFA
# 2    2026-03-09         Sale       Free Hold  JUMEIRAH VILLAGE CIRCLE
# 3    2026-03-06         Sale       Free Hold  JUMEIRAH VILLAGE CIRCLE
# 4    2026-03-06         Sale       Free Hold  INTERNATIONAL CITY PH 1
#
#   PROP_SB_TYPE_EN  TRANS_VALUE  ACTUAL_AREA ROOMS_EN  \
# 0            Flat    2600000.0       140.95    2 B/R
# 1            Flat    2731642.0       134.46    2 B/R
# 2            Flat     620000.0        42.87   Studio
# 3            Flat     540000.0        36.86   Studio
# 4            Flat     515000.0        66.50    1 B/R
#
#              NEAREST_METRO_EN     NEAREST_MALL_EN  \
# 0  Business Bay Metro Station          Dubai Mall
# 1  Business Bay Metro Station          Dubai Mall
# 2       Nakheel Metro Station         Marina Mall
# ...

# %% [markdown]
# # Dubai Real Estate Analytics
#
# ## Objective
#
# This project investigates Dubai property prices using data analysis and machine learning techniques.
#
# ## Research Question
#
# Which factors have the strongest influence on Dubai property prices?
#
# ## Dataset
#
# The dataset contains property information including:
# - Location
# - Property type
# - Size
# - Bedrooms
# - Price

# %%
df.shape
# Out:
# (18085, 15)

# %% [markdown]
# check number of rows and columns: Meaning (18085 properties, 15 variables)

# %%
df.columns
# Out:
# Index(['INSTANCE_DATE', 'PROCEDURE_EN', 'IS_FREE_HOLD_EN', 'AREA_EN',
#        'PROP_SB_TYPE_EN', 'TRANS_VALUE', 'ACTUAL_AREA', 'ROOMS_EN',
#        'NEAREST_METRO_EN', 'NEAREST_MALL_EN', 'NEAREST_LANDMARK_EN',
#        'PROJECT_EN', 'price_per_sqm', 'size_category', 'value_band'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18085 entries, 0 to 18084
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   INSTANCE_DATE        18085 non-null  object
#  1   PROCEDURE_EN         18085 non-null  object
#  2   IS_FREE_HOLD_EN      18085 non-null  object
#  3   AREA_EN              18085 non-null  object
#  4   PROP_SB_TYPE_EN      18085 non-null  object
#  5   TRANS_VALUE          18085 non-null  float64
#  6   ACTUAL_AREA          18085 non-null  float64
#  7   ROOMS_EN             17723 non-null  object
#  8   NEAREST_METRO_EN     14513 non-null  object
#  9   NEAREST_MALL_EN      14332 non-null  object
#  10  NEAREST_LANDMARK_EN  16433 non-null  object
#  11  PROJECT_EN           14018 non-null  object
#  12  price_per_sqm        18085 non-null  float64
#  13  size_category        18085 non-null  object
#  14  value_band           18085 non-null  object
# ...

# %% [markdown]
# You want to identify:
#
# numbers/ text/ missing data

# %%
df.describe()
# Out:
#         TRANS_VALUE   ACTUAL_AREA  price_per_sqm
# count  1.808500e+04  18085.000000   1.808500e+04
# mean   1.857787e+06     94.380744   1.864498e+04
# std    2.756622e+06     77.235185   2.056915e+04
# min    2.312380e+03      7.310000   3.310000e+01
# 25%    7.300000e+05     54.770000   1.139983e+04
# 50%    1.190000e+06     78.110000   1.579517e+04
# 75%    2.098512e+06    115.530000   2.259084e+04
# max    1.000000e+08   4827.040000   2.207993e+06

# %% [markdown]
# This gives:
#
# average price/ minimum/ maximum/ standard deviation

# %%
df.isnull().sum()
# Out:
# INSTANCE_DATE             0
# PROCEDURE_EN              0
# IS_FREE_HOLD_EN           0
# AREA_EN                   0
# PROP_SB_TYPE_EN           0
# TRANS_VALUE               0
# ACTUAL_AREA               0
# ROOMS_EN                362
# NEAREST_METRO_EN       3572
# NEAREST_MALL_EN        3753
# NEAREST_LANDMARK_EN    1652
# PROJECT_EN             4067
# price_per_sqm             0
# size_category             0
# value_band                0
# dtype: int64

# %% [markdown]
# This tells you what cleaning is needed.

# %%
import matplotlib.pyplot as plt

df['TRANS_VALUE'].hist(figsize=(8,5))

plt.xlabel("TRANS(VALUE)")
plt.ylabel("Number of Properties")
plt.title("Dubai Property Price Distribution")

plt.show()
